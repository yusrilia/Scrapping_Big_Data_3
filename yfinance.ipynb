# %% [markdown]
# # Kelompok 3 Big Data Platform

# %% [markdown]
# Anggota:
# - Mochamad Zidan Rusdhiana (2305464)
# - Muhammad Daffa Ma'arif (2305771)
# - Yusrilia Hidayanti (2306828)
# - Ismail Fatih Raihan (2307840)
# - Hafsah Hamidah (2311474)
# - Yahyo Abdullozoda (2313368)

# %% [markdown]
# ## Latar Belakang

# %% [markdown]
# Dalam analisis pasar keuangan, data saham real-time dan historis sangat penting untuk pengambilan keputusan. yfinance menyediakan data saham dalam format JSON atau DataFrame melalui API, memungkinkan akses ke harga saham, laporan keuangan, dan indikator pasar. Proses ingestion dilakukan dengan memanggil API, kemudian data diformat dan disimpan dalam database seperti PostgreSQL untuk analisis struktural atau MongoDB untuk penyimpanan fleksibel. Dengan penyimpanan yang terstruktur, data ini dapat digunakan untuk analisis tren, prediksi harga, dan integrasi dengan sumber data lainnya.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Ingest Data Saham dan Data Historis Emiten di Indonesia menggunakan library yfinance

# %% [markdown]
# Alur Kerja Ingest
# 1. Koneksi ke Sumber Data
#     - Gunakan pustaka yfinance untuk mengakses data saham.
#     - Tentukan daftar simbol saham yang akan diambil.
# 2. Pengambilan Data (Fetching Data)
#     - Gunakan yfinance.Ticker() untuk mendapatkan informasi saham (info).
#     - Ambil data historis harga saham dengan history(period="1y") untuk mendapatkan data selama 1 tahun terakhir.
#     - Pastikan data berhasil diambil sebelum melanjutkan ke tahap berikutnya.
# 3. Transformasi Data
#     - Konversi data historis dari DataFrame menjadi list of dictionaries agar kompatibel dengan penyimpanan di database.
#     - Pastikan data memiliki format yang seragam untuk mempermudah analisis lebih lanjut.

# %%
import yfinance as yf

stocks = [
    # BANKING SECTOR
    "BBRI.JK", "BMRI.JK", "BBCA.JK", "BBNI.JK", "BJBR.JK", "BJTM.JK", "AGRO.JK", "BBKP.JK", "BDMN.JK", 
    "NISP.JK", "PNBN.JK", "BCIC.JK", "MAYA.JK", "ARTO.JK", "BTPS.JK", "AMAR.JK", "NOBU.JK", "BINA.JK",
    "BSIM.JK", "BNGA.JK", "BGTG.JK", "BNLI.JK", "BABP.JK", "BBYB.JK", "BEKS.JK", "BMAS.JK", "BOSS.JK",

    # ENERGY SECTOR
    "ADRO.JK", "ITMG.JK", "PTBA.JK", "MEDC.JK", "PGAS.JK", "ELSA.JK", "AKRA.JK", "HRUM.JK", "INDY.JK",
    "MBAP.JK", "BIPI.JK", "DOID.JK", "ENRG.JK", "RAJA.JK", "GEMS.JK", "TPIA.JK", "BRPT.JK", "ESSA.JK",
    "PSAB.JK", "SMMT.JK", "BREN.JK", "TOBA.JK", "CNKO.JK", "MARI.JK", "BUMI.JK", "SUGI.JK", "DWGL.JK",

    # CONSUMER GOODS
    "UNVR.JK", "ICBP.JK", "INDF.JK", "MYOR.JK", "SIDO.JK", "KAEF.JK", "PEHA.JK", "KLBF.JK", "GOOD.JK",
    "DMND.JK", "KINO.JK", "ALTO.JK", "AISA.JK", "HOKI.JK", "CLEO.JK", "ULTJ.JK", "ADES.JK", "ROTI.JK",
    "FOOD.JK", "CMRY.JK", "SAPX.JK", "STTP.JK", "MRAT.JK", "FITT.JK", "NAYZ.JK", "TSPC.JK", "CBMF.JK",

    # INFRASTRUCTURE & TELECOMMUNICATION
    "TLKM.JK", "EXCL.JK", "ISAT.JK", "FREN.JK", "TOWR.JK", "SUPR.JK", "JSMR.JK", "CMNP.JK", "WIKA.JK",
    "PTPP.JK", "ADHI.JK", "WSKT.JK", "WTON.JK", "KRAS.JK", "SMGR.JK", "INTP.JK", "LPKR.JK", "PWON.JK",
    "NRCA.JK", "TOTL.JK", "ACST.JK", "MTLA.JK", "PPRO.JK", "KIJA.JK", "JRPT.JK", "CTRA.JK", "DMAS.JK",

    # PROPERTY & REAL ESTATE
    "BSDE.JK", "CTRA.JK", "SMRA.JK", "ASRI.JK", "DMAS.JK", "COWL.JK", "OMRE.JK", "KIJA.JK", "MTLA.JK",
    "JRPT.JK", "PPRO.JK", "NIRO.JK", "BKSL.JK", "URBN.JK", "PLIN.JK", "MKPI.JK", "PWON.JK", "LMAS.JK",
    "LAMI.JK", "DILD.JK", "ELTY.JK", "RDTX.JK", "TARA.JK", "LPCK.JK", "MDLN.JK", "SIPD.JK", "JGLE.JK",

    # TRANSPORTATION & LOGISTICS
    "GIAA.JK", "ASSA.JK", "SMDR.JK", "TMAS.JK", "HITS.JK", "SAFE.JK", "JSMR.JK", "MCOL.JK", "WEHA.JK",
    "BIRD.JK", "SAPX.JK", "BLTA.JK", "MBTO.JK", "IPCC.JK", "DEPO.JK", "NELY.JK", "CMPP.JK", "JAYA.JK",
    "ADES.JK", "TRUK.JK", "WEHA.JK", "LION.JK", "TAXI.JK", "JAYA.JK",

    # METAL & MINING
    "ANTM.JK", "INCO.JK", "MDKA.JK", "PSAB.JK", "TINS.JK", "HRTA.JK", "ZINC.JK", "DKFT.JK", "BOSS.JK",
    "KKGI.JK", "BIPI.JK", "TOBA.JK", "GEMS.JK", "DOID.JK", "MBAP.JK", "CITA.JK", "NICL.JK",
    "NIKL.JK", "SMRU.JK", "PTRO.JK", "SPTO.JK", "MAMI.JK", "LSIP.JK", "MGRO.JK", "TAPG.JK", "STAA.JK",

    # RETAIL & DISTRIBUTION
    "ACES.JK", "MAPI.JK", "RALS.JK", "LPPF.JK", "MPPA.JK", "AMRT.JK", "ERAA.JK", "CSAP.JK", "PRDA.JK",
    "TELE.JK", "KIOS.JK", "DIVA.JK", "DIGI.JK", "NFCX.JK", "GLOB.JK", "MCAS.JK", "TFAS.JK", "MDKA.JK",
    "DNET.JK", "PDES.JK", "MIDI.JK", "MAPA.JK", "OPMS.JK", "BATA.JK", "UNVR.JK", "INAF.JK",

    # FINTECH & TECHNOLOGY
    "GOTO.JK", "BUKA.JK", "DCII.JK", "EDGE.JK", "MTDL.JK", "SKYB.JK", "ALDO.JK", "YELO.JK", "MPXL.JK",
    "MCAS.JK", "BALI.JK", "TFAS.JK", "DIVA.JK", "NFCX.JK", "WIFI.JK", "DMMX.JK", "BIRD.JK", "DEPO.JK",
    "SLIS.JK", "TRIO.JK", "TECH.JK", "CLAY.JK", "LUCY.JK", "AGII.JK", "AXIO.JK",

    # MANUFACTURING
    "SMSM.JK", "AUTO.JK", "ASII.JK", "GJTL.JK", "IMAS.JK", "SPMA.JK", "INDS.JK", "PRAS.JK", "SSTM.JK",
    "INDR.JK", "ICBP.JK", "INDF.JK", "PICO.JK", "LTLS.JK", "INTA.JK", "MASA.JK", "DUTI.JK", "BTON.JK",
    "DKFT.JK", "TRST.JK", "STTP.JK", "ALMI.JK", "CASS.JK", "AGRO.JK", "BTON.JK", "GGRP.JK", "BRNA.JK",
]

# Dictionary untuk menyimpan data saham
stock_data = {}

success_list = []
failed_list = {}

for stock in stocks:
    try:
        ticker = yf.Ticker(stock)
        info = ticker.info
        history = ticker.history(period="1y")

        # Konversi DataFrame ke format JSON-friendly
        history.reset_index(inplace=True)
        history["Date"] = history["Date"].astype(str)  # Ubah Timestamp ke String

        # Buat dokumen terpisah untuk MongoDB
        stock_doc = {
            "_id": stock,  # Gunakan kode saham sebagai ID unik
            "info": info,
            "history": history.to_dict(orient="records")  # List format
        }
        stock_data[stock] = stock_doc
        
        success_list.append(stock)
    except Exception as e:
        failed_list[stock] = str(e)

# Print hasil setelah semua proses selesai
print("\nData berhasil diambil untuk:")
print(", ".join(success_list))

if failed_list:
    print("\nData gagal diambil untuk:")
    for stock, error in failed_list.items():
        print(f"- {stock}: {error}")

print("\nPengambilan data selesai!")
# Out:
# $LAMI.JK: possibly delisted; no price data found  (period=1y)
#
# Data berhasil diambil untuk:
# BBRI.JK, BMRI.JK, BBCA.JK, BBNI.JK, BJBR.JK, BJTM.JK, AGRO.JK, BBKP.JK, BDMN.JK, NISP.JK, PNBN.JK, BCIC.JK, MAYA.JK, ARTO.JK, BTPS.JK, AMAR.JK, NOBU.JK, BINA.JK, BSIM.JK, BNGA.JK, BGTG.JK, BNLI.JK, BABP.JK, BBYB.JK, BEKS.JK, BMAS.JK, BOSS.JK, ADRO.JK, ITMG.JK, PTBA.JK, MEDC.JK, PGAS.JK, ELSA.JK, AKRA.JK, HRUM.JK, INDY.JK, MBAP.JK, BIPI.JK, DOID.JK, ENRG.JK, RAJA.JK, GEMS.JK, TPIA.JK, BRPT.JK, ESSA.JK, PSAB.JK, SMMT.JK, BREN.JK, TOBA.JK, CNKO.JK, MARI.JK, BUMI.JK, SUGI.JK, DWGL.JK, UNVR.JK, ICBP.JK, INDF.JK, MYOR.JK, SIDO.JK, KAEF.JK, PEHA.JK, KLBF.JK, GOOD.JK, DMND.JK, KINO.JK, ALTO.JK, AISA.JK, HOKI.JK, CLEO.JK, ULTJ.JK, ADES.JK, ROTI.JK, FOOD.JK, CMRY.JK, SAPX.JK, STTP.JK, MRAT.JK, FITT.JK, NAYZ.JK, TSPC.JK, CBMF.JK, TLKM.JK, EXCL.JK, ISAT.JK, FREN.JK, TOWR.JK, SUPR.JK, JSMR.JK, CMNP.JK, WIKA.JK, PTPP.JK, ADHI.JK, WSKT.JK, WTON.JK, KRAS.JK, SMGR.JK, INTP.JK, LPKR.JK, PWON.JK, NRCA.JK, TOTL.JK, ACST.JK, MTLA.JK, PPRO.JK, KIJA.JK, JRPT.JK, CTRA.JK, DMAS.JK, BSDE.JK, CTRA.JK, SMRA.JK, ASRI.JK, DMAS.JK, COWL.JK, OMRE.JK, KIJA.JK, MTLA.JK, JRPT.JK, PPRO.JK, NIRO.JK, BKSL.JK, URBN.JK, PLIN.JK, MKPI.JK, PWON.JK, LMAS.JK, LAMI.JK, DILD.JK, ELTY.JK, RDTX.JK, TARA.JK, LPCK.JK, MDLN.JK, SIPD.JK, JGLE.JK, GIAA.JK, ASSA.JK, SMDR.JK, TMAS.JK, HITS.JK, SAFE.JK, JSMR.JK, MCOL.JK, WEHA.JK, BIRD.JK, SAPX.JK, BLTA.JK, MBTO.JK, IPCC.JK, DEPO.JK, NELY.JK, CMPP.JK, JAYA.JK, ADES.JK, TRUK.JK, WEHA.JK, LION.JK, TAXI.JK, JAYA.JK, ANTM.JK, INCO.JK, MDKA.JK, PSAB.JK, TINS.JK, HRTA.JK, ZINC.JK, DKFT.JK, BOSS.JK, KKGI.JK, BIPI.JK, TOBA.JK, GEMS.JK, DOID.JK, MBAP.JK, CITA.JK, NICL.JK, NIKL.JK, SMRU.JK, PTRO.JK, SPTO.JK, MAMI.JK, LSIP.JK, MGRO.JK, TAPG.JK, STAA.JK, ACES.JK, MAPI.JK, RALS.JK, LPPF.JK, MPPA.JK, AMRT.JK, ERAA.JK, CSAP.JK, PRDA.JK, TELE.JK, KIOS.JK, DIVA.JK, DIGI.JK, NFCX.JK, GLOB.JK, MCAS.JK, TFAS.JK, MDKA.JK, DNET.JK, PDES.JK, MIDI.JK, MAPA.JK, OPMS.JK, BATA.JK, UNVR.JK, INAF.JK, GOTO.JK, BUKA.JK, DCII.JK, EDGE.JK, MTDL.JK, SKYB.JK, ALDO.JK, YELO.JK, MPXL.JK, MCAS.JK, BALI.JK, TFAS.JK, DIVA.JK, NFCX.JK, WIFI.JK, DMMX.JK, BIRD.JK, DEPO.JK, SLIS.JK, TRIO.JK, TECH.JK, CLAY.JK, LUCY.JK, AGII.JK, AXIO.JK, SMSM.JK, AUTO.JK, ASII.JK, GJTL.JK, IMAS.JK, SPMA.JK, INDS.JK, PRAS.JK, SSTM.JK, INDR.JK, ICBP.JK, INDF.JK, PICO.JK, LTLS.JK, INTA.JK, MASA.JK, DUTI.JK, BTON.JK, DKFT.JK, TRST.JK, STTP.JK, ALMI.JK, CASS.JK, AGRO.JK, BTON.JK, GGRP.JK, BRNA.JK
#
# Pengambilan data selesai!

# %%
import pandas as pd
# Preview info saham BBRI (Bank Rakyat Indonesia)

stock_data["BBRI.JK"]["info"]
# Out:
# {'address1': 'Gedung BRI',
#  'address2': 'Jalan Jenderal Sudirman Kav.44-46 Tromol Pos 1094/1000',
#  'city': 'Jakarta',
#  'zip': '10210',
#  'country': 'Indonesia',
#  'phone': '62 21 251 0244',
#  'fax': '62 21 250 0077',
#  'website': 'https://bri.co.id',
#  'industry': 'Banks - Regional',
#  'industryKey': 'banks-regional',
#  'industryDisp': 'Banks - Regional',
#  'sector': 'Financial Services',
#  'sectorKey': 'financial-services',
#  'sectorDisp': 'Financial Services',
#  'longBusinessSummary': 'PT Bank Rakyat Indonesia (Persero) Tbk provides various banking products and services in Indonesia and internationally. The company offers savings and current accounts; time, foreign currency time, and on call deposits; mortgage, working capital, investment, franchise, and cash collateral loans, as well as supply and value chain financing and bank guarantees; and micro, small and medium, and program loans. It also provides bill payment, deposit, online transaction, remittance, money transfer, business, financial, institutional, treasury and global, custodian, trustee, and cash management services. In addition, the company offers investment products and services; trade finance and services, and transaction banking services, including import and export, standby L/C, money changer, BRI RTE online system services, as well as letters of credit; credit cards; and wealth management, merchant, and digital banking services. Further, it provides life and general insurance, securities underwriting and brokerage, and venture capital services. The company was founded in 1895 and is headquartered in Jakarta, Indonesia.',
#  'fullTimeEmployees': 81171,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. .  Sunarso',
#    'age': 61,
#    'title': 'President Director',
#    'yearBorn': 1963,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Agus  Winardono',
#    'age': 59,
#    'title': 'Director of Human Capital & Director',
#    'yearBorn': 1965,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Amam  Sukriyanto',
#    'age': 56,
#    'title': 'Director of Commercial, Small & Medium Business and Director',
#    'yearBorn': 1968,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Agus  Noorsanto',
#    'age': 60,
#    'title': 'Wholesale & Institutional Business Director and Director',
#    'yearBorn': 1964,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'irWebsite': 'http://www.irbri.com/',
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 3840.0,
#  'open': 3870.0,
#  'dayLow': 3870.0,
#  'dayHigh': 3980.0,
#  'regularMarketPreviousClose': 3840.0,
#  'regularMarketOpen': 3870.0,
#  'regularMarketDayLow': 3870.0,
#  'regularMarketDayHigh': 3980.0,
#  'dividendRate': 370.0,
#  'dividendYield': 9.64,
#  'exDividendDate': 1735257600,
#  'payoutRatio': 0.92730004,
#  'fiveYearAvgDividendYield': 4.84,
#  'beta': 0.614,
#  'trailingPE': 9.925309,
#  'forwardPE': 8.996116,
#  'volume': 213514100,
#  'regularMarketVolume': 213514100,
#  'averageVolume': 282458916,
#  'averageVolume10days': 423976020,
#  'averageDailyVolume10Day': 423976020,
#  'bid': 3960.0,
#  'ask': 3970.0,
#  'bidSize': 0,
#  'askSize': 0,
#  'marketCap': 596570017890304,
#  'fiftyTwoWeekLow': 3360.0,
#  'fiftyTwoWeekHigh': 6450.0,
#  'priceToSalesTrailing12Months': 4.497934,
#  'fiftyDayAverage': 4032.4,
#  'twoHundredDayAverage': 4534.65,
#  'trailingAnnualDividendRate': 0.0,
#  'trailingAnnualDividendYield': 0.0,
#  'currency': 'IDR',
#  'tradeable': False,
#  'enterpriseValue': 644413202104320,
#  'profitMargins': 0.45354998,
#  'floatShares': 69979530757,
#  'sharesOutstanding': 150648995840,
#  'heldPercentInsiders': 0.5575,
#  'heldPercentInstitutions': 0.23883,
#  'impliedSharesOutstanding': 150648995840,
#  'bookValue': 2104.85,
#  'priceToBook': 1.8813691,
#  'lastFiscalYearEnd': 1735603200,
#  'nextFiscalYearEnd': 1767139200,
#  'mostRecentQuarter': 1735603200,
#  'earningsQuarterlyGrowth': -0.063,
#  'netIncomeToCommon': 60154888323072,
#  'trailingEps': 398.98,
#  'forwardEps': 440.19,
#  'lastSplitFactor': '5:1',
#  'lastSplitDate': 1510272000,
#  'enterpriseToRevenue': 4.859,
#  '52WeekChange': -0.38313252,
#  'SandP52WeekChange': 0.12036967,
#  'lastDividendValue': 135.0,
#  'lastDividendDate': 1735257600,
#  'quoteType': 'EQUITY',
#  'currentPrice': 3960.0,
#  'targetHighPrice': 6300.0,
#  'targetLowPrice': 3600.0,
#  'targetMeanPrice': 5001.7144,
#  'targetMedianPrice': 5000.0,
#  'recommendationMean': 1.47619,
#  'recommendationKey': 'strong_buy',
#  'numberOfAnalystOpinions': 21,
#  'totalCash': 131498367778816,
#  'totalCashPerShare': 872.878,
#  'totalDebt': 191323764162560,
#  'totalRevenue': 132632012652544,
#  'revenuePerShare': 879.909,
#  'returnOnAssets': 0.030639999,
#  'returnOnEquity': 0.18961,
#  'grossProfits': 130599796867072,
#  'operatingCashflow': 14440601747456,
#  'earningsGrowth': -0.064,
#  'revenueGrowth': -0.069,
#  'grossMargins': 0.0,
#  'ebitdaMargins': 0.0,
#  'operatingMargins': 0.41215,
#  'financialCurrency': 'IDR',
#  'symbol': 'BBRI.JK',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Delayed Quote',
#  'triggerable': False,
#  'customPriceAlertConfidence': 'LOW',
#  'corporateActions': [],
#  'regularMarketTime': 1741237199,
#  'exchange': 'JKT',
#  'messageBoardId': 'finmb_8391292',
#  'exchangeTimezoneName': 'Asia/Jakarta',
#  'exchangeTimezoneShortName': 'WIB',
#  'gmtOffSetMilliseconds': 25200000,
#  'market': 'id_market',
#  'esgPopulated': False,
#  'regularMarketChangePercent': 3.125,
#  'regularMarketPrice': 3960.0,
#  'marketState': 'REGULAR',
#  'fiftyDayAverageChange': -72.3999,
#  'fiftyDayAverageChangePercent': -0.017954545,
#  'twoHundredDayAverageChange': -574.6499,
#  'twoHundredDayAverageChangePercent': -0.1267242,
#  'sourceInterval': 10,
#  'exchangeDataDelayedBy': 10,
#  'averageAnalystRating': '1.5 - Strong Buy',
#  'cryptoTradeable': False,
#  'shortName': 'Bank Rakyat Indonesia (Persero)',
#  'longName': 'PT Bank Rakyat Indonesia (Persero) Tbk',
#  'hasPrePostMarketData': False,
#  'firstTradeDateMilliseconds': 1068429600000,
#  'regularMarketChange': 120.0,
#  'regularMarketDayRange': '3870.0 - 3980.0',
#  'fullExchangeName': 'Jakarta',
#  'averageDailyVolume3Month': 282458916,
#  'fiftyTwoWeekLowChange': 600.0,
#  'fiftyTwoWeekLowChangePercent': 0.17857143,
#  'fiftyTwoWeekRange': '3360.0 - 6450.0',
#  'fiftyTwoWeekHighChange': -2490.0,
#  'fiftyTwoWeekHighChangePercent': -0.3860465,
#  'fiftyTwoWeekChangePercent': -38.31325,
#  'earningsTimestamp': 1739271540,
#  'earningsTimestampStart': 1745492340,
#  'earningsTimestampEnd': 1745841600,
#  'earningsCallTimestampStart': 1739329200,
#  'earningsCallTimestampEnd': 1739329200,
#  'isEarningsDateEstimate': True,
#  'epsTrailingTwelveMonths': 398.98,
#  'epsForward': 440.19,
#  'epsCurrentYear': 394.80927,
#  'priceEpsCurrentYear': 10.03016,
#  'trailingPegRatio': 7.4311}

# %%
# Preview data historis BBRI (Bank Mandiri)

history_df = pd.DataFrame(stock_data["BBRI.JK"]["history"])
history_df.head()
# Out:
#                         Date         Open         High          Low  \
# 0  2024-03-06 00:00:00+07:00  5687.143626  5780.375488  5687.143626
# 1  2024-03-07 00:00:00+07:00  5780.375628  5850.299526  5780.375628
# 2  2024-03-08 00:00:00+07:00  5850.299249  5966.839075  5826.991284
# 3  2024-03-13 00:00:00+07:00  5920.223423  6013.455288  5920.223423
# 4  2024-03-14 00:00:00+07:00  5976.517717  6000.714145  5855.535577
#
#          Close     Volume  Dividends  Stock Splits
# 0  5780.375488   84108800        0.0           0.0
# 1  5803.683594  117724700        0.0           0.0
# 2  5920.223145  163060000        0.0           0.0
# 3  5966.839355  195173100        0.0           0.0
# 4  5952.321289  271254000      235.0           0.0

# %%
# Preview info saham BMRI (Bank Rakyat Indonesia)
stock_data["BMRI.JK"]["info"]
# Out:
# {'address1': 'Jalan Jenderal Gatot Subroto Kav. 36-38',
#  'city': 'Jakarta',
#  'zip': '12190',
#  'country': 'Indonesia',
#  'phone': '62 21 5299 7777',
#  'fax': '62 21 5299 7735',
#  'website': 'https://bankmandiri.co.id',
#  'industry': 'Banks - Regional',
#  'industryKey': 'banks-regional',
#  'industryDisp': 'Banks - Regional',
#  'sector': 'Financial Services',
#  'sectorKey': 'financial-services',
#  'sectorDisp': 'Financial Services',
#  'longBusinessSummary': 'PT Bank Mandiri (Persero) Tbk provides various banking products and services to individuals and businesses in Indonesia, Singapore, Hong Kong, Timor Leste, Shanghai, Malaysia, England, and the Cayman Islands. It offers savings and current accounts, multicurrency, payroll, NOW, and foreign currency savings accounts; personal, mortgage, micro enterprise, small and medium enterprises, working capital, and investment loans; corporate, credit, and debit cards; digital banking; and e-banking services. The company also provides life, health, and accident insurance products, as well as investment products; cash management, bill collection, payment, trade finance, money transfer, remittance, and wealth management services; and treasury services, including cash transaction, hedging, and investment products. It operates branch offices, sub-branch offices, and overseas branch offices; and ATM facilities. The company was founded in 1998 and is headquartered in Jakarta, Indonesia.',
#  'fullTimeEmployees': 38898,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Darmawan  Junaidi',
#    'age': 58,
#    'title': 'President Director',
#    'yearBorn': 1966,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Alexandra  Askandar',
#    'age': 52,
#    'title': 'Vice President Director',
#    'yearBorn': 1972,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Sigit  Prastowo',
#    'age': 53,
#    'title': 'Director of Finance & Strategies and Director',
#    'yearBorn': 1971,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Toni Eko Boy Subari',
#    'age': 60,
#    'title': 'Director of Operation & Director',
#    'yearBorn': 1964,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Laurensius  Teiseran',
#    'age': 35,
#    'title': 'Group Head of Investor Relation',
#    'yearBorn': 1989,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Agus Dwi Handaya',
#    'age': 54,
#    'title': 'Director of Compliance & Human Resources and Director',
#    'yearBorn': 1970,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Dedy Teguh Krisnawan',
#    'title': 'Group Head of Legal',
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Aquarius  Rudianto',
#    'age': 57,
#    'title': 'Director of Network & Retail Banking and Director',
#    'yearBorn': 1967,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Riduan  Ahmad',
#    'age': 54,
#    'title': 'Director of Corporate Banking & Director',
#    'yearBorn': 1970,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Rohan  Hafas',
#    'age': 63,
#    'title': 'Director of Institutional Relations & Director',
#    'yearBorn': 1961,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'executiveTeam': [],
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 4860.0,
#  'open': 4910.0,
#  'dayLow': 4890.0,
#  'dayHigh': 4980.0,
#  'regularMarketPreviousClose': 4860.0,
#  'regularMarketOpen': 4910.0,
#  'regularMarketDayLow': 4890.0,
#  'regularMarketDayHigh': 4980.0,
#  'dividendRate': 353.96,
#  'dividendYield': 7.28,
#  'exDividendDate': 1710892800,
#  'payoutRatio': 0.59220004,
#  'fiveYearAvgDividendYield': 4.83,
#  'beta': 0.568,
#  'trailingPE': 8.247181,
#  'forwardPE': 7.430518,
#  'volume': 89750000,
#  'regularMarketVolume': 89750000,
#  'averageVolume': 160850839,
#  'averageVolume10days': 221821940,
#  'averageDailyVolume10Day': 221821940,
#  'bid': 4930.0,
#  'ask': 4940.0,
#  'bidSize': 0,
#  'askSize': 0,
#  'marketCap': 460133167529984,
#  'fiftyTwoWeekLow': 4550.0,
#  'fiftyTwoWeekHigh': 7550.0,
#  'priceToSalesTrailing12Months': 3.4150884,
#  'fiftyDayAverage': 5506.4,
#  'twoHundredDayAverage': 6316.475,
#  'trailingAnnualDividendRate': 0.0,
#  'trailingAnnualDividendYield': 0.0,
#  'currency': 'IDR',
#  'tradeable': False,
#  'enterpriseValue': 606566017400832,
#  'profitMargins': 0.41402,
#  'floatShares': 37182133333,
#  'sharesOutstanding': 93333299200,
#  'heldPercentInsiders': 0.53963,
#  'heldPercentInstitutions': 0.28557,
#  'impliedSharesOutstanding': 93333299200,
#  'bookValue': 3040.676,
#  'priceToBook': 1.6213499,
#  'lastFiscalYearEnd': 1735603200,
#  'nextFiscalYearEnd': 1767139200,
#  'mostRecentQuarter': 1735603200,
#  'earningsQuarterlyGrowth': -0.139,
#  'netIncomeToCommon': 55782741639168,
#  'trailingEps': 597.78,
#  'forwardEps': 663.48,
#  'lastSplitFactor': '2:1',
#  'lastSplitDate': 1680566400,
#  'enterpriseToRevenue': 4.502,
#  '52WeekChange': -0.31549293,
#  'SandP52WeekChange': 0.12036967,
#  'lastDividendValue': 353.95752,
#  'lastDividendDate': 1710892800,
#  'quoteType': 'EQUITY',
#  'currentPrice': 4930.0,
#  'targetHighPrice': 8800.0,
#  'targetLowPrice': 5100.0,
#  'targetMeanPrice': 6817.636,
#  'targetMedianPrice': 6774.0,
#  'recommendationMean': 1.54545,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 22,
#  'totalCash': 175344187342848,
#  'totalCashPerShare': 1878.688,
#  'totalDebt': 298631961772032,
#  'totalRevenue': 134735363833856,
#  'revenuePerShare': 1443.593,
#  'returnOnAssets': 0.026589999,
#  'returnOnEquity': 0.20355,
#  'grossProfits': 132070705725440,
#  'operatingCashflow': -208081954799616,
#  'earningsGrowth': -0.139,
#  'revenueGrowth': 0.028,
#  'grossMargins': 0.0,
#  'ebitdaMargins': 0.0,
#  'operatingMargins': 0.50118,
#  'financialCurrency': 'IDR',
#  'symbol': 'BMRI.JK',
#  'language': 'en-US',
#  'region': 'US',
#  'typeDisp': 'Equity',
#  'quoteSourceName': 'Delayed Quote',
#  'triggerable': False,
#  'customPriceAlertConfidence': 'LOW',
#  'exchange': 'JKT',
#  'messageBoardId': 'finmb_8387507',
#  'exchangeTimezoneName': 'Asia/Jakarta',
#  'exchangeTimezoneShortName': 'WIB',
#  'gmtOffSetMilliseconds': 25200000,
#  'market': 'id_market',
#  'esgPopulated': False,
#  'regularMarketChangePercent': 1.4403292,
#  'regularMarketPrice': 4930.0,
#  'marketState': 'REGULAR',
#  'shortName': 'Bank Mandiri (Persero) Tbk',
#  'longName': 'PT Bank Mandiri (Persero) Tbk',
#  'corporateActions': [],
#  'regularMarketTime': 1741237199,
#  'hasPrePostMarketData': False,
#  'firstTradeDateMilliseconds': 1058148000000,
#  'regularMarketChange': 70.0,
#  'regularMarketDayRange': '4890.0 - 4980.0',
#  'fullExchangeName': 'Jakarta',
#  'averageDailyVolume3Month': 160850839,
#  'fiftyTwoWeekLowChange': 380.0,
#  'fiftyTwoWeekLowChangePercent': 0.083516486,
#  'fiftyTwoWeekRange': '4550.0 - 7550.0',
#  'fiftyTwoWeekHighChange': -2620.0,
#  'fiftyTwoWeekHighChangePercent': -0.34701988,
#  'fiftyTwoWeekChangePercent': -31.549294,
#  'earningsTimestamp': 1737543540,
#  'earningsTimestampStart': 1745837940,
#  'earningsTimestampEnd': 1746187200,
#  'earningsCallTimestampStart': 1737507600,
#  'earningsCallTimestampEnd': 1737507600,
#  'isEarningsDateEstimate': True,
#  'epsTrailingTwelveMonths': 597.78,
#  'epsForward': 663.48,
#  'epsCurrentYear': 623.10175,
#  'priceEpsCurrentYear': 7.9120307,
#  'fiftyDayAverageChange': -576.3999,
#  'fiftyDayAverageChangePercent': -0.10467818,
#  'twoHundredDayAverageChange': -1386.4751,
#  'twoHundredDayAverageChangePercent': -0.21950139,
#  'sourceInterval': 10,
#  'exchangeDataDelayedBy': 10,
#  'averageAnalystRating': '1.5 - Buy',
#  'cryptoTradeable': False,
#  'trailingPegRatio': 0.9882}

# %%
# Preview data historis BMRI (Bank Mandiri)
history_df = pd.DataFrame(stock_data["BBRI.JK"]["history"])
history_df.head()
# Out:
#                         Date         Open         High          Low  \
# 0  2024-03-06 00:00:00+07:00  5687.143626  5780.375488  5687.143626
# 1  2024-03-07 00:00:00+07:00  5780.375628  5850.299526  5780.375628
# 2  2024-03-08 00:00:00+07:00  5850.299249  5966.839075  5826.991284
# 3  2024-03-13 00:00:00+07:00  5920.223423  6013.455288  5920.223423
# 4  2024-03-14 00:00:00+07:00  5976.517717  6000.714145  5855.535577
#
#          Close     Volume  Dividends  Stock Splits
# 0  5780.375488   84108800        0.0           0.0
# 1  5803.683594  117724700        0.0           0.0
# 2  5920.223145  163060000        0.0           0.0
# 3  5966.839355  195173100        0.0           0.0
# 4  5952.321289  271254000      235.0           0.0

# %% [markdown]
# ### Menyimapan Data Frame ke dalam file JSON

# %%
import json

# Fixing the issue: We should ensure history is a DataFrame before invoking reset_index()
for stock in stock_data:
    # Check if it is a DataFrame
    if isinstance(stock_data[stock]["history"], pd.DataFrame):
        stock_data[stock]["history"] = stock_data[stock]["history"].reset_index().to_dict(orient="records")
    else:
        # If it is already a dictionary (list of records), keep it as is
        stock_data[stock]["history"] = stock_data[stock]["history"]

# Save the corrected data to a JSON file
with open("stock_yfinance.json", "w", encoding="utf-8") as json_file:
    json.dump(stock_data, json_file, ensure_ascii=False, indent=4)

print("\nData telah disimpan dalam file stock_yfinance.json")
# Out:
# Data telah disimpan dalam file stock_yfinance.json

# %% [markdown]
# <hr>

# %%
import json
import pandas as pd

# List untuk menyimpan emiten sebagai array of objects
stock_list = []

for stock, data in stock_data.items():
    stock_entry = {
        "info": data["info"],
        "history": data["history"] if isinstance(data["history"], list) 
                  else data["history"].reset_index().to_dict(orient="records")
    }
    stock_list.append(stock_entry)

# Simpan dalam file JSON
with open("stock_yfinance.json", "w", encoding="utf-8") as json_file:
    json.dump(stock_list, json_file, ensure_ascii=False, indent=4)

print("\nData telah disimpan dalam file stock_yfinance.json dalam format array of objects.")
# Out:
# Data telah disimpan dalam file stock_yfinance.json dalam format array of objects.

# %% [markdown]
# ## Penyimpanan data Ingestion ke MongoDB

# %% [markdown]
# Alur Kerja Penyimpanan
# 1. Koneksi ke MongoDB
#    - Gunakan pustaka `pymongo` untuk menghubungkan Python dengan MongoDB.
#    - Tentukan database (`big_data_platform`) dan koleksi (`stocks`) tempat data akan disimpan.
# 2. Pengambilan Data dari yFinance
#    - Gunakan `yfinance.Ticker()` untuk mendapatkan informasi saham (`info`) dan data historis (`history`).
#    - Data historis dalam bentuk DataFrame dikonversi ke list of dictionaries agar kompatibel dengan MongoDB.
# 3. Transformasi Data
#    - Format data yang akan disimpan mencakup symbol, info, dan history.
#    - Pastikan setiap saham memiliki struktur data yang sama untuk kemudahan analisis.
# 4. Penyimpanan ke MongoDB
#    - Data dimasukkan ke koleksi MongoDB menggunakan `insert_one()`.
#    - Jika ada banyak data, gunakan `insert_many()` untuk efisiensi.
# 5. Error Handling
#    - Tangkap kemungkinan error saat mengambil atau menyimpan data.
#    - Catat saham yang gagal agar bisa dicoba ulang atau dianalisis penyebabnya.
# 6. Verifikasi Penyimpanan
#    - Gunakan perintah MongoDB seperti `db.stocks.findOne()` untuk memastikan data tersimpan dengan benar.
#    - Cek menggunakan MongoDB Compass atau Mongo Shell untuk melihat struktur data.

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=07965d0a-800f-4d85-aac5-2d21187ba25a' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
